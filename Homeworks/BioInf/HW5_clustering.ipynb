# %% [markdown]
# <a href="https://colab.research.google.com/github/Existanze54/sirius-machine-learning-2025/blob/main/Homeworks/BioInf/HW5_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#    ## Основные алгоритмы машинного обучения
#
# ## Домашнее задание 5
#
# ### Кластеризация. K-means. DBSCAN

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %% [markdown]
# В этом задании предлагается сравнить поведение алгоритмов кластеризации K-means и DBSCAN на данных разной формы.

# %% [markdown]
# ## I. K-means

# %% [markdown]
# ### Задача 1. make_blobs

# %% [markdown]
# Сгенерируем датасет с помощью `make_blobs`.

# %%
from sklearn.datasets import make_blobs

X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)

plt.scatter(X[:, 0], X[:, 1], c=y_true, s=50);

# %% [markdown]
# Примените к сгенерированным данным метод K-means и визуализируйте результат кластеризации.

# %%
# your code here

# %% [markdown]
# Объясните, почему в этом случае K-means отрабатывает хорошо.

# %%
# your conclusions here

# %% [markdown]
# ### Задача 2. make_moons

# %% [markdown]
# Теперь сгенерируем датасет более сложной формы с помощью `make_moons`.

# %%
from sklearn.datasets import make_moons

X, y_true = make_moons(200, noise=.05, random_state=0)

plt.scatter(X[:, 0], X[:, 1], c=y_true, s=50);

# %% [markdown]
# Примените к сгенерированным данным метод K-means и визуализируйте результат кластеризации.

# %%
# your code here

# %% [markdown]
# Поэкспериментируйте с различными значениями гиперпараметров для K-means.
#
#
# Есть ли надежда на получение хорошей кластеризации в данном случае? Объясните, почему.

# %%
# your code here

# %%
# your conclusions here

# %% [markdown]
# ## II. DBSCAN

# %% [markdown]
# ### Задача

# %% [markdown]
# Примените на сгенерированных ранее данных `make_blobs` и `make_moons` метод DBSCAN и визуализируйте результат кластеризации.
#
# Подберите параметры `eps` и `min_samples`, чтобы алгоритм выделял корректное число кластеров.

# %%
# your code here

# %% [markdown]
# ## III. Сравнение методов

# %% [markdown]
# Напишите небольшой сравнительный вывод:
#
# * для каких данных предпочтителен K-means, а когда лучше справится DBSCAN;
#
# * какие ограничения есть у каждого алгоритма;
#
# * какой алгоритм легче применять с точки зрения пользователя.

# %%
# your conclusions here
