# %% [markdown]
# <a href="https://colab.research.google.com/github/Existanze54/sirius-machine-learning-2025/blob/main/Homeworks/GenTech/HW5_RF_GT25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашка 5. Случайный лес

# %% [markdown]
# ### imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Задача. ГЭБ

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# Поработаем с датасетом [BBBP](https://pubs.acs.org/doi/abs/10.1021/ci300124c), содержащем данные об проницаемости лекарствами гемато-энцефалического барьера.

# %%
! wget -q https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/BBBP.csv

# %%
df = pd.read_csv('BBBP.csv')
df.head(2)

# %% [markdown]
# Нам доступны только SMILES, так что рассчитаем дескрипторы (признаки) с уже знакомым `datamol`.

# %%
! pip -q install datamol

# %%
# %%capture --no-display
import datamol as dm

df['mol'] = df['smiles'].map(dm.to_mol)
df = df.dropna()

y = df['p_np']
X = dm.descriptors.batch_compute_many_descriptors(
    df['mol'], progress=True, batch_size=16, n_jobs=-1,
)

# %% [markdown]
# ### Пункт 1
# Разбейте на обучающую и валидационную выборки. Оцените $Accuracy$ для `RF` с параметрами по умолчанию.

# %%
# your code here

# %% [markdown]
# ### Пункт 2
# Отберите 50% (`threshold='median'`) наиважнейших признаков (по мнению `RF` с параметрами по умолчанию) с `SelectFromModel`. Оцените $Accuracy$ на новом наборе признаков.

# %%
# your code here

# %% [markdown]
# ### Пункт 3
# Постройте график, отражающий зависимость $Accuracy$ от числа деревьев, а так же от другого гиперпараметра на выбор.

# %%
# your code here

# %% [markdown]
# ### Пункт 4
# Изобразите важность признаков отсортированной столбчатой диаграммой.

# %%
# your code here
