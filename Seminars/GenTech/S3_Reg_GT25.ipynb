# %% [markdown]
# <a href="https://colab.research.google.com/github/Existanze54/sirius-machine-learning-2025/blob/main/Seminars/GenTech/S3_Reg_GT25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Семинар 3. Регрессия ближайших соседей, линейная регрессия

# %% [markdown]
# ### Давайте импортируем все разом

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Сегодня понадобится много всяких моделек

# %%
from sklearn.neighbors import KNeighborsRegressor as kNN
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.linear_model import Lasso, LassoCV

# %% [markdown]
# Не забываем про подготовку данных

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Для удобства можно написать подобную функцию

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

def train_test_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    return pd.DataFrame({'MAE': [mae], 'R2': [r2]})

# %% [markdown]
# ### Задача 1. Диабет

# %% [markdown]
# Целевой переменной в этой задаче является количественная мера прогрессии диабета за год. Сравните точность (можно любыми метриками для регрессии, но R2 — классика) для для обычной линейной регрессии, а так же с L2- и L1-регуляризацией. Постройте графики зависимости точности от силы регуляризации с и без стандартизацией признаков.

# %%
from sklearn.datasets import load_diabetes
data = load_diabetes(as_frame=True, scaled=False)

# %%
# your code here

# %% [markdown]
# ### Задача 2. Цены домов в Калифорнии

# %% [markdown]
# Целевая переменная — медианная стоимость дома в округах Калифорнии, выраженная в сотнях тысяч долларов. Попробуйте подобрать гиперпараметры (число соседей и меру расстояния) для регрессора kNN. Сравните качество с LinReg, RidgeCV, LassoCV и ElasticNetCV. Постройте столбчатую диаграмму для визуальной оценки.

# %%
from sklearn.datasets import fetch_california_housing
# your code here

# %%
# your code here
